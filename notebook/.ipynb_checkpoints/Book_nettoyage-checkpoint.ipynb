# %% [markdown]
# # <center> Loan_Prediction </center>
# __________________
#
#
# ![image.png](attachment:image.png)
#
# ____________________
#
#  -Description des variables :
#
#     -Loan_ID Unique Loan ID : Identifiant unique
#     -Gender - Male/ Female : Genre Male/Female pour Homme et Femme
#     -Married - Applicant married (Y/N) : Savoir si la personne est mariée ou non
#     -Dependents - Number of dependents : Nombre de personnes à charge
#     -Education - Applicant Education (Graduate/ Under Graduate) : Formation du candidat (diplômé/non diplômé)
#     -Self_Employed - Self employed (Y/N) : Travailleurs indépendants (Oui/Non)
#     -ApplicantIncome - Applicant income : Revenu du demandeur
#     -CoapplicantIncome - Coapplicant income : Revenu d'un second demandeur
#     -LoanAmount - Loan amount in thousands : Montant du prêt en milliers
#     -Loan_Amount_Term - Term of loan in months : Durée du prêt en mois
#     -Credit_History - credit history meets guidelines : Antécédents de crédit payé à temps
#     -Property_Area - Urban/ Semi Urban/ Rural - Zone_de_propriété (Urbain/ Semi-urbain/ Rural)
#     -Loan_Status - Loan approved (Y/N) - Prêt approuvé (O/N)
#
# ____________________
#
# L'Etude est de savoir si un pret peut être accordé en fonction des parametres d'entrées.
# On est donc dans un problème lié à la classification.
#
# Nous allons commencer par étudier les données, les visualiser et les nettoyer.
# Ensuite nous nous pencherons sur les différents algorithmse de classification.
# Puis nous continuerons par afficher les metrics pertinents et tirer les conclusions de l'étude.
#
# _________________________

# %% [markdown]
# ### <center>  Exploration de données </center>

# %%
# importer les librairie
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import missingno as mno

# %%
# importer les données
df = pd.read_csv("datasets/train.csv", delimiter = ",")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
# Voir la description du dataset
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
# information sur le dataset, sur le type de colonne
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# ___________________________

# %%
# Compter le nombre de valeurs null par colonne dans le dataset
df.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#Affichage des données manquantes
mno.matrix(df, figsize = (20, 6))

# %% [raw]
# On constate qu'on a un dataset de 614 lignes:
# Parmis ces 614 lignes on a 149 valeurs manquantes.
#
# Il va falloir réfléchir à l'imputation des valeurs pendant l'étude.
# Et sur l'importance des features contenant les valeurs manquantes.

# %% [markdown]
# __________________

# %%
# Réflexion sur le type de features
numeric_features = df.select_dtypes(include = ['int64', 'float64']).columns
categorical_features = df.iloc[:, ::].select_dtypes(include = ['object']).columns

print("Numeric features:", numeric_features.to_list())
print("Categorical features:", categorical_features.to_list())
# Out:
# Numeric features: ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History']
# Categorical features: ['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Property_Area', 'Loan_Status']

# %% [raw]
# Reflexion sur le type de colonnes :
#
# Constat : On constate dans notre dataset qu'on a :
# 4 colonnes de type numerique.
#
# Nous incluons la colonne 'Credit_history' dans les catégories
# 8 colonnes de type categorie.

# %% [markdown]
# ___________

# %%
# visualisation des différentes valeurs par catégorie

tab_categorical = ['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Property_Area', 'Credit_History', 'Loan_Amount_Term']
for i in tab_categorical:
    values = df[i].value_counts(normalize = True)
    print(values)
    print ("\n\n", '≡'*40, "\n")
# Out:
# Male      0.813644
# Female    0.186356
# Name: Gender, dtype: float64
#
#
#  ≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡
#
# Yes    0.651391
# No     0.348609
# Name: Married, dtype: float64
#
#
#  ≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡
#
# 0     0.575960
# 1     0.170284
# 2     0.168614
# 3+    0.085142
# Name: Dependents, dtype: float64
#
#
#  ≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡
#
# Graduate        0.781759
# Not Graduate    0.218241
# Name: Education, dtype: float64
#
#
#  ≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡
#
# No     0.859107
# Yes    0.140893
# Name: Self_Employed, dtype: float64
#
#
#  ≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡
#
# Semiurban    0.379479
# Urban        0.328990
# Rural        0.291531
# Name: Property_Area, dtype: float64
#
#
#  ≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡
#
# 1.0    0.842199
# 0.0    0.157801
# Name: Credit_History, dtype: float64
#
#
#  ≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡
#
# 360.0    0.853333
# 180.0    0.073333
# ...

# %% [markdown]
# __________________________________

# %% [markdown]
# ### <center>  Visualisation de données </center>

# %%
# Mise en avant des features de catégorie en fonction du target 

tab_numerical = ['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Property_Area', 'Credit_History', 'Loan_Amount_Term']
 
fig,axes = plt.subplots(4,2,figsize=(12,15))
for idx,cat_col in enumerate(tab_categorical):
    row,col = idx//2,idx%2
    sns.countplot(x=cat_col,data=df,hue='Loan_Status',ax=axes[row,col])


plt.subplots_adjust(hspace=1)

# %% [raw]
# Constat :
#
# A l'aide des visualisations précédentes, on peut constater que certaines features de type categorie ont une certaine influence sur la target :
#
# ----------------------
# - Credit_history : Quand le crédit history est a 1, on a 4 fois plus de chance d'obtenir un crédit (loan_status = Y)
# --> C'est donc une feature importante
# ----------------------
# - Loan_Amount_Term : Quand tu choisie de rembourser le crédit en 180 ou 360 mensualité, on a 2 fois plus de chance d'obtenir un crédit à contrario, 2 fois moins pour 480 mensualités.
# --> C'est donc une feature importante
# ----------------------
# - Self_Employed : On constate que l'on soit indépendant ou non, les chances d'avoir un crédit sont les mêmes.
# --> Cette feature n'influe pas sur le résultat
# ----------------------
# - Property_Area : On constate pour cette feature influe sur la target.
#     - Urban : les personnes en zone urbaine ont 50% de chance d'obtenir un crédit. On peut penser qu'il s'agit de personne                 possédant des petits appartements, donc un patrimoine moins important.
#     - Rural : les personnes en zone rural ont 30 % de chance d'obtenir un crédit. On peut penser que ses personnes sont                   souvent loin des villes, la valeurs du patrimoine est plus faible.
#     - Semi_urbain : les personnes en zone semi-urbaine ont 75% de chance d'obtenir un crédit. On peut penser que ses                       personnes sont proche des grandes villes et dispose d'un grand patrimoine.
# --> Cette feature influe sur la target
# ----------------------
# - Education : Les personnes diplomés ont pus de chance d'obtenir un crédit que les personnes n'en n ayant pas.
# --> Cette feature influe sur la target
# ----------------------
# - Dependents : Les personnes ayant 0, 1, 3+ de personnes à charge on 50% de chance d'obetenir un crédit on pourrait penser que cette feature est peut importante, mais lorsque de l'on a 2 personnes a charge les chances passe à 75%.
# --> Cette feature a une importance sur la target
# ----------------------
# - Married : On constate que les personnes mariés on plus de chance d'obtenir un crédit.
# --> cette feature import sur le target
# ----------------------
# - Gender : Que ce soit un male ou female, les chances d'obtenir un crédit sont les mêmes.
# --> cette feature n'est pas importante

# %%
# Mise en avant des outliers pour les features numerique en fonction du target

tab_numerical = ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount']

fig,axes = plt.subplots(1,3,figsize=(17,5))
for i,cat_col in enumerate(tab_numerical):
    sns.boxplot(y=cat_col,data=df,x='Loan_Status',ax=axes[i], showmeans = True)
    
plt.subplots_adjust(hspace=1)

# %% [raw]
# Constat :
#
# En analysant les boxplots, on constate que pour les colonnes numériques, il n'y a pas de relation significative avec le statut d'approbation du prêt.
#
# Ceci dit, nous avons des outliers et il serait judicieux d'appliquer un filtre.
